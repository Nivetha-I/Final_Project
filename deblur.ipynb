# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from scipy.signal import deconvolve

# Load the original image
image_path = 'C:\\Users\\admin\\Desktop\\Final_Project2_Imageprocessing\\WienerImageDeblurringExample_02.png'
Ioriginal = cv2.imread(image_path)

# Check if the image is loaded successfully
if Ioriginal is None:
    print(f"Error: Unable to load the image from '{image_path}'.")
    exit()

# Create a motion blur PSF
PSF_size = 21
PSF_length = 11
PSF = cv2.getGaussianKernel(PSF_size, PSF_length)
PSF = PSF @ PSF.T

# Convert the original image to double precision
Idouble = Ioriginal.astype(float) / 255.0

# Apply motion blur to the original image
blurred = cv2.filter2D(Idouble, -1, PSF, borderType=cv2.BORDER_CONSTANT)

# Wiener deconvolution
wnr1, _ = deconvolve(blurred, PSF)

# Clip values to [0, 1]
wnr1 = np.clip(wnr1, 0, 1)

# Display the restored image
plt.imshow(wnr1)
plt.title('Restored Blurred Image')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 28
#      25 blurred = cv2.filter2D(Idouble, -1, PSF, borderType=cv2.BORDER_CONSTANT)
#      27 # Wiener deconvolution
# ---> 28 wnr1, _ = deconvolve(blurred, PSF)
#      30 # Clip values to [0, 1]
#      31 wnr1 = np.clip(wnr1, 0, 1)
#
# File c:\Users\admin\Desktop\Final_Project2_Imageprocessing\.venv\Lib\site-packages\scipy\signal\_signaltools.py:2282, in deconvolve(signal, divisor)
#    2280 den = np.atleast_1d(divisor)
#    2281 if num.ndim > 1:
# -> 2282     raise ValueError("signal must be 1-D.")
#    2283 if den.ndim > 1:
#    2284     raise ValueError("divisor must be 1-D.")
#
# ValueError: signal must be 1-D.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from scipy.signal import deconvolve

# Load the original image
image_path = 'C:\\Users\\admin\\Desktop\\Final_Project2_Imageprocessing\\WienerImageDeblurringExample_02.png'
Ioriginal = cv2.imread(image_path)

# Check if the image is loaded successfully
if Ioriginal is None:
    print(f"Error: Unable to load the image from '{image_path}'.")
    exit()

# Create a motion blur PSF
PSF_size = 21
PSF_length = 11
PSF = cv2.getGaussianKernel(PSF_size, PSF_length)
PSF = PSF @ PSF.T

# Convert the original image to double precision
Idouble = Ioriginal.astype(float) / 255.0

# Apply motion blur to the original image
blurred = cv2.filter2D(Idouble, -1, PSF, borderType=cv2.BORDER_CONSTANT)

# Reshape the signals to 1D arrays
blurred_1d = blurred.flatten()
PSF_1d = PSF.flatten()

# Wiener deconvolution
wnr1, _ = deconvolve(blurred_1d, PSF_1d)

# Reshape the result back to 2D
wnr1 = wnr1.reshape(Idouble.shape)

# Clip values to [0, 1]
wnr1 = np.clip(wnr1, 0, 1)

# Display the restored image
plt.imshow(wnr1)
plt.title('Restored Blurred Image')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 35
#      32 wnr1, _ = deconvolve(blurred_1d, PSF_1d)
#      34 # Reshape the result back to 2D
# ---> 35 wnr1 = wnr1.reshape(Idouble.shape)
#      37 # Clip values to [0, 1]
#      38 wnr1 = np.clip(wnr1, 0, 1)
#
# ValueError: cannot reshape array of size 428734 into shape (339,422,3)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from scipy.signal import deconvolve

# Load the original image
image_path = 'C:\\Users\\admin\\Desktop\\Final_Project2_Imageprocessing\\WienerImageDeblurringExample_02.png'
Ioriginal = cv2.imread(image_path)

# Check if the image is loaded successfully
if Ioriginal is None:
    print(f"Error: Unable to load the image from '{image_path}'.")
    exit()

# Create a motion blur PSF
PSF_size = 21
PSF_length = 11
PSF = cv2.getGaussianKernel(PSF_size, PSF_length)
PSF = PSF @ PSF.T

# Convert the original image to double precision
Idouble = Ioriginal.astype(float) / 255.0

# Apply motion blur to the original image
blurred = cv2.filter2D(Idouble, -1, PSF, borderType=cv2.BORDER_CONSTANT)

# Reshape the signals to 1D arrays
blurred_1d = blurred.flatten()
PSF_1d = PSF.flatten()

# Wiener deconvolution
wnr1, _ = deconvolve(blurred_1d, PSF_1d)

# Reshape the result back to 2D
wnr1_2d = wnr1.reshape(Idouble.shape)

# Clip values to [0, 1]
wnr1_2d = np.clip(wnr1_2d, 0, 1)

# Convert back to the intensity range of the original image
wnr1_restored = (wnr1_2d * 255).astype(np.uint8)

# Display the restored image
plt.imshow(cv2.cvtColor(wnr1_restored, cv2.COLOR_BGR2RGB))
plt.title('Restored Blurred Image')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 35
#      32 wnr1, _ = deconvolve(blurred_1d, PSF_1d)
#      34 # Reshape the result back to 2D
# ---> 35 wnr1_2d = wnr1.reshape(Idouble.shape)
#      37 # Clip values to [0, 1]
#      38 wnr1_2d = np.clip(wnr1_2d, 0, 1)
#
# ValueError: cannot reshape array of size 428734 into shape (339,422,3)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from scipy.signal import deconvolve

# Load the original image
image_path = 'C:\\Users\\admin\\Desktop\\Final_Project2_Imageprocessing\\WienerImageDeblurringExample_02.png'
Ioriginal = cv2.imread(image_path)

# Check if the image is loaded successfully
if Ioriginal is None:
    print(f"Error: Unable to load the image from '{image_path}'.")
    exit()

# Create a motion blur PSF
PSF_size = 21
PSF_length = 11
PSF = cv2.getGaussianKernel(PSF_size, PSF_length)
PSF = PSF @ PSF.T

# Convert the original image to double precision
Idouble = Ioriginal.astype(float) / 255.0

# Apply motion blur to the original image
blurred = cv2.filter2D(Idouble, -1, PSF, borderType=cv2.BORDER_CONSTANT)

# Reshape the signals to 1D arrays
blurred_1d = blurred.flatten()
PSF_1d = PSF.flatten()

# Wiener deconvolution
wnr1, _ = deconvolve(blurred_1d, PSF_1d)

# Reshape the result back to 2D
wnr1_2d = wnr1.reshape(Idouble.shape[0], Idouble.shape[1])

# Clip values to [0, 1]
wnr1_2d = np.clip(wnr1_2d, 0, 1)

# Convert back to the intensity range of the original image
wnr1_restored = (wnr1_2d * 255).astype(np.uint8)

# Display the restored image
plt.imshow(cv2.cvtColor(wnr1_restored, cv2.COLOR_BGR2RGB))
plt.title('Restored Blurred Image')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 35
#      32 wnr1, _ = deconvolve(blurred_1d, PSF_1d)
#      34 # Reshape the result back to 2D
# ---> 35 wnr1_2d = wnr1.reshape(Idouble.shape[0], Idouble.shape[1])
#      37 # Clip values to [0, 1]
#      38 wnr1_2d = np.clip(wnr1_2d, 0, 1)
#
# ValueError: cannot reshape array of size 428734 into shape (339,422)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from scipy.signal import deconvolve

# Load the original image
image_path = 'C:\\Users\\admin\\Desktop\\Final_Project2_Imageprocessing\\WienerImageDeblurringExample_02.png'
Ioriginal = cv2.imread(image_path)

# Check if the image is loaded successfully
if Ioriginal is None:
    print(f"Error: Unable to load the image from '{image_path}'.")
    exit()

# Create a motion blur PSF
PSF_size = 21
PSF_length = 11
PSF = cv2.getGaussianKernel(PSF_size, PSF_length)
PSF = PSF @ PSF.T

# Convert the original image to double precision
Idouble = Ioriginal.astype(float) / 255.0

# Apply motion blur to the original image
blurred = cv2.filter2D(Idouble, -1, PSF, borderType=cv2.BORDER_CONSTANT)

# Wiener deconvolution
wnr1, _ = deconvolve(blurred.flatten(), PSF.flatten())

# Clip values to [0, 1]
wnr1_2d = np.clip(wnr1, 0, 1)

# Convert back to the intensity range of the original image
wnr1_restored = (wnr1_2d.reshape(Idouble.shape) * 255).astype(np.uint8)

# Display the restored image
plt.imshow(cv2.cvtColor(wnr1_restored, cv2.COLOR_BGR2RGB))
plt.title('Restored Blurred Image')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 34
#      31 wnr1_2d = np.clip(wnr1, 0, 1)
#      33 # Convert back to the intensity range of the original image
# ---> 34 wnr1_restored = (wnr1_2d.reshape(Idouble.shape) * 255).astype(np.uint8)
#      36 # Display the restored image
#      37 plt.imshow(cv2.cvtColor(wnr1_restored, cv2.COLOR_BGR2RGB))
#
# ValueError: cannot reshape array of size 428734 into shape (339,422,3)

# %%
Ioriginal = imread('cameraman.tif');
imshow(Ioriginal)
print('Original Image')
PSF = fspecial('motion',21,11);
Idouble = im2double(Ioriginal);
blurred = imfilter(Idouble,PSF,'conv','circular');
imshow(blurred)
print('Blurred Image')

# %%
from scipy.signal import deconvolve
from scipy.signal import convolve2d
import numpy as np
from scipy.fft import fft2, ifft2

# Assuming you have the blurred image 'blurred' and the PSF 'PSF' from your previous code

# Wiener deconvolution
blurred_1d = blurred.flatten()
PSF_1d = PSF.flatten()

# Perform deconvolution in the frequency domain
blurred_freq = fft2(blurred)
PSF_freq = fft2(PSF, s=blurred.shape)
wnr1_freq = blurred_freq / PSF_freq

# Perform inverse Fourier transform to get the deblurred image
wnr1 = np.abs(ifft2(wnr1_freq))

# Clip values to [0, 1]
wnr1 = np.clip(wnr1, 0, 1)

# Display the deblurred image
imshow(wnr1)
print('Deblurred Image')

# %%
from scipy.misc import imread, imshow
from scipy.signal import deconvolve
from scipy.signal import convolve2d
import numpy as np
from scipy.fft import fft2, ifft2

# Read the original image
Ioriginal = imread('WienerImageDeblurringExample_02.png')
imshow(Ioriginal)
print('Original Image')

# Assuming you have the PSF and motion-blurred image as in your previous code

# Wiener deconvolution
blurred_1d = blurred.flatten()
PSF_1d = PSF.flatten()

# Perform deconvolution in the frequency domain
blurred_freq = fft2(blurred)
PSF_freq = fft2(PSF, s=blurred.shape)
wnr1_freq = blurred_freq / PSF_freq

# Perform inverse Fourier transform to get the deblurred image
wnr1 = np.abs(ifft2(wnr1_freq))

# Clip values to [0, 1]
wnr1 = np.clip(wnr1, 0, 1)

# Display the deblurred image
imshow(wnr1)
print('Deblurred Image')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from scipy.misc import imread, imshow
#       2 from scipy.signal import deconvolve
#       3 from scipy.signal import convolve2d
#
# ImportError: cannot import name 'imread' from 'scipy.misc' (c:\Users\admin\Desktop\Final_Project2_Imageprocessing\.venv\Lib\site-packages\scipy\misc\__init__.py)

# %%
import imageio
import matplotlib.pyplot as plt
from scipy.signal import deconvolve
from scipy.fft import fft2, ifft2
import numpy as np

# Read the original image
Ioriginal = imageio.imread('WienerImageDeblurringExample_02.png')
plt.imshow(Ioriginal, cmap='gray')
plt.title('Original Image')
plt.show()

# Assuming you have the PSF and motion-blurred image as in your previous code

# Wiener deconvolution
blurred_1d = blurred.flatten()
PSF_1d = PSF.flatten()

# Perform deconvolution in the frequency domain
blurred_freq = fft2(blurred)
PSF_freq = fft2(PSF, s=blurred.shape)
wnr1_freq = blurred_freq / PSF_freq

# Perform inverse Fourier transform to get the deblurred image
wnr1 = np.abs(ifft2(wnr1_freq))

# Clip values to [0, 1]
wnr1 = np.clip(wnr1, 0, 1)

# Display the deblurred image
plt.imshow(wnr1, cmap='gray')
plt.title('Deblurred Image')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_20040\3209957854.py:8: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   Ioriginal = imageio.imread('WienerImageDeblurringExample_02.png')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 21
#      19 # Perform deconvolution in the frequency domain
#      20 blurred_freq = fft2(blurred)
# ---> 21 PSF_freq = fft2(PSF, s=blurred.shape)
#      22 wnr1_freq = blurred_freq / PSF_freq
#      24 # Perform inverse Fourier transform to get the deblurred image
#
# File c:\Users\admin\Desktop\Final_Project2_Imageprocessing\.venv\Lib\site-packages\scipy\fft\_backend.py:28, in _ScipyBackend.__ua_function__(method, args, kwargs)
# ...

# %%
import imageio
import matplotlib.pyplot as plt
from scipy.signal import deconvolve
from scipy.fft import fft2, ifft2
import numpy as np

# Read the original image
Ioriginal = imageio.imread('WienerImageDeblurringExample_02.png')
plt.imshow(Ioriginal, cmap='gray')
plt.title('Original Image')
plt.show()

# Assuming you have the PSF and motion-blurred image as in your previous code

# Wiener deconvolution
blurred_1d = blurred.flatten()
PSF_1d = PSF.flatten()

# Perform deconvolution in the frequency domain
blurred_freq = fft2(blurred)
PSF_freq = fft2(PSF, s=blurred.shape)
wnr1_freq = blurred_freq / PSF_freq

# Perform inverse Fourier transform to get the deblurred image
wnr1 = np.abs(ifft2(wnr1_freq))

# Clip values to [0, 1]
wnr1 = np.clip(wnr1, 0, 1)

# Display the deblurred image
plt.imshow(wnr1, cmap='gray')
plt.title('Deblurred Image')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_20040\3209957854.py:8: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   Ioriginal = imageio.imread('WienerImageDeblurringExample_02.png')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 21
#      19 # Perform deconvolution in the frequency domain
#      20 blurred_freq = fft2(blurred)
# ---> 21 PSF_freq = fft2(PSF, s=blurred.shape)
#      22 wnr1_freq = blurred_freq / PSF_freq
#      24 # Perform inverse Fourier transform to get the deblurred image
#
# File c:\Users\admin\Desktop\Final_Project2_Imageprocessing\.venv\Lib\site-packages\scipy\fft\_backend.py:28, in _ScipyBackend.__ua_function__(method, args, kwargs)
# ...

# %%
import imageio
import matplotlib.pyplot as plt
from scipy.signal import deconvolve
from scipy.fft import fft2, ifft2
import numpy as np

# Read the original image
Ioriginal = imageio.imread('WienerImageDeblurringExample_02.png')
plt.imshow(Ioriginal, cmap='gray')
plt.title('Original Image')
plt.show()

# Assuming you have the PSF and motion-blurred image as in your previous code

# Wiener deconvolution
blurred_1d = blurred.flatten()
PSF_1d = PSF.flatten()

# Perform deconvolution in the frequency domain
blurred_freq = fft2(blurred)
PSF_freq = fft2(PSF, s=blurred_freq.shape)  # Use the shape of the blurred image
wnr1_freq = blurred_freq / PSF_freq

# Perform inverse Fourier transform to get the deblurred image
wnr1 = np.abs(ifft2(wnr1_freq))

# Clip values to [0, 1]
wnr1 = np.clip(wnr1, 0, 1)

# Display the deblurred image
plt.imshow(wnr1, cmap='gray')
plt.title('Deblurred Image')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_20040\1116264346.py:8: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   Ioriginal = imageio.imread('WienerImageDeblurringExample_02.png')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 21
#      19 # Perform deconvolution in the frequency domain
#      20 blurred_freq = fft2(blurred)
# ---> 21 PSF_freq = fft2(PSF, s=blurred_freq.shape)  # Use the shape of the blurred image
#      22 wnr1_freq = blurred_freq / PSF_freq
#      24 # Perform inverse Fourier transform to get the deblurred image
#
# ...

# %%
import imageio
import matplotlib.pyplot as plt
from scipy.signal import deconvolve, convolve2d, wiener

# Read the original image
Ioriginal = imageio.imread('WienerImageDeblurringExample_02.png')
plt.imshow(Ioriginal, cmap='gray')
plt.title('Original Image')
plt.show()

# Assuming you have the PSF and motion-blurred image as in your previous code

# Perform Wiener deconvolution
wnr1 = wiener(blurred, PSF)

# Clip values to [0, 1]
wnr1 = np.clip(wnr1, 0, 1)

# Display the deblurred image
plt.imshow(wnr1, cmap='gray')
plt.title('Deblurred Image')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_20040\45736062.py:6: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   Ioriginal = imageio.imread('WienerImageDeblurringExample_02.png')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 14
#       9 plt.show()
#      11 # Assuming you have the PSF and motion-blurred image as in your previous code
#      12
#      13 # Perform Wiener deconvolution
# ---> 14 wnr1 = wiener(blurred, PSF)
#      16 # Clip values to [0, 1]
#      17 #wnr1 = np.clip(wnr1, 0, 1)
#      18
#      19 # Display the deblurred image
#      20 plt.imshow(wnr1, cmap='gray')
#
# ...

# %%
import cv2
import numpy as np
from deblur import deblur_image

# Load the blurred image
blurred_image = cv2.imread('WienerImageDeblurringExample_02.png')

# Deblur the image
deblurred_image = deblur_image(blurred_image)

# Display the original and deblurred images
cv2.imshow('Blurred Image', blurred_image)
cv2.imshow('Deblurred Image', deblurred_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 3
#       1 import cv2
#       2 import numpy as np
# ----> 3 from deblur import deblur_image
#       5 # Load the blurred image
#       6 blurred_image = cv2.imread('WienerImageDeblurringExample_02.png')
#
# ModuleNotFoundError: No module named 'deblur'
